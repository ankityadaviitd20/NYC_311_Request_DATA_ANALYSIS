# %%
import pandas as pd
import numpy as np

# %%
df_original=pd.read_csv('../data/nyc_311_request_data_dec_2025.csv')
df=df_original.copy()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 323343 entries, 0 to 323342
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      323343 non-null  int64
#  1   created_date                    323343 non-null  str
#  2   closed_date                     303798 non-null  str
#  3   agency                          323343 non-null  str
#  4   agency_name                     323343 non-null  str
#  5   complaint_type                  323343 non-null  str
#  6   descriptor                      319605 non-null  str
#  7   descriptor_2                    144037 non-null  str
#  8   location_type                   292803 non-null  str
#  9   incident_zip                    321092 non-null  float64
#  10  incident_address                313995 non-null  str
#  11  street_name                     313989 non-null  str
#  12  cross_street_1                  201526 non-null  str
#  13  cross_street_2                  201565 non-null  str
#  14  intersection_street_1           194339 non-null  str
#  15  intersection_street_2           194445 non-null  str
#  16  address_type                    322055 non-null  str
#  17  city                            313403 non-null  str
#  18  landmark                        177541 non-null  str
#  19  facility_type                   640 non-null     str
#  20  status                          323343 non-null  str
#  21  due_date                        1416 non-null    str
#  22  resolution_description          316596 non-null  str
#  23  resolution_action_updated_date  318395 non-null  str
#  24  community_board                 323343 non-null  str
#  25  council_district                318970 non-null  float64
#  26  police_precinct                 323343 non-null  str
#  27  bbl                             297957 non-null  float64
#  28  borough                         323343 non-null  str
#  29  x_coordinate_state_plane        320248 non-null  float64
#  30  y_coordinate_state_plane        320256 non-null  float64
#  31  open_data_channel_type          323343 non-null  str
#  32  park_facility_name              323125 non-null  str
#  33  park_borough                    323343 non-null  str
#  34  vehicle_type                    11236 non-null   str
#  35  taxi_company_borough            241 non-null     str
#  36  taxi_pick_up_location           2952 non-null    str
#  37  bridge_highway_name             1461 non-null    str
#  38  bridge_highway_direction        802 non-null     str
#  39  road_ramp                       663 non-null     str
#  40  bridge_highway_segment          1453 non-null    str
#  41  latitude                        320246 non-null  float64
#  42  longitude                       320246 non-null  float64
#  43  location                        320246 non-null  str
# dtypes: float64(7), int64(1), str(36)
# memory usage: 333.1 MB

# %%
df.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    67352282  2025-12-31T00:00:00.000  2026-01-09T00:00:01.000  DOHMH
# 1    67334470  2025-12-30T23:59:35.000  2025-12-31T05:46:02.000   NYPD
# 2    67343383  2025-12-30T23:59:31.000  2025-12-31T09:13:42.000    HPD
# 3    67337570  2025-12-30T23:59:28.000  2025-12-31T01:03:53.000   NYPD
# 4    67343958  2025-12-30T23:59:22.000  2025-12-31T15:30:10.000   NYPD
#
#                                          agency_name       complaint_type  \
# 0            Department of Health and Mental Hygiene       Food Poisoning
# 1                    New York City Police Department  Noise - Residential
# 2  Department of Housing Preservation and Develop...       HEAT/HOT WATER
# 3                    New York City Police Department      Illegal Parking
# 4                    New York City Police Department  Noise - Residential
#
#                       descriptor descriptor_2               location_type  \
# 0                         1 or 2          NaN  Restaurant/Bar/Deli/Bakery
# 1               Loud Music/Party          NaN  Residential Building/House
# 2                 APARTMENT ONLY      NO HEAT        RESIDENTIAL BUILDING
# 3  Posted Parking Sign Violation          NaN             Street/Sidewalk
# 4               Loud Music/Party          NaN  Residential Building/House
#
#    incident_zip  ... vehicle_type taxi_company_borough taxi_pick_up_location  \
# 0       10003.0  ...          NaN                  NaN                   NaN
# 1       10472.0  ...          NaN                  NaN                   NaN
# 2       10467.0  ...          NaN                  NaN                   NaN
# 3       11201.0  ...          NaN                  NaN                   NaN
# 4       11208.0  ...          NaN                  NaN                   NaN
#
#   bridge_highway_name bridge_highway_direction road_ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   bridge_highway_segment   latitude  longitude  \
# 0                    NaN  40.726183 -73.986326
# 1                    NaN  40.832973 -73.876391
# 2                    NaN  40.884346 -73.878834
# 3                    NaN  40.692591 -73.990963
# 4                    NaN  40.669321 -73.876734
#
#                                    location
# 0  POINT (-73.986326176505 40.726183323174)
# 1   POINT (-73.876391113118 40.83297318207)
# 2    POINT (-73.878834348657 40.8843456267)
# 3  POINT (-73.990963235578 40.692590626589)
# 4  POINT (-73.876734057579 40.669320633906)
#
# [5 rows x 44 columns]

# %%
null_percentage=(df.isnull().sum()*100/len(df)).sort_values(ascending=False).round(2)
null_percentage
# Out:
# taxi_company_borough              99.93
# facility_type                     99.80
# road_ramp                         99.79
# bridge_highway_direction          99.75
# due_date                          99.56
# bridge_highway_segment            99.55
# bridge_highway_name               99.55
# taxi_pick_up_location             99.09
# vehicle_type                      96.53
# descriptor_2                      55.45
# landmark                          45.09
# intersection_street_1             39.90
# intersection_street_2             39.86
# cross_street_1                    37.67
# cross_street_2                    37.66
# location_type                      9.45
# bbl                                7.85
# closed_date                        6.04
# city                               3.07
# street_name                        2.89
# incident_address                   2.89
# resolution_description             2.09
# resolution_action_updated_date     1.53
# council_district                   1.35
# descriptor                         1.16
# location                           0.96
# longitude                          0.96
# latitude                           0.96
# x_coordinate_state_plane           0.96
# y_coordinate_state_plane           0.95
# incident_zip                       0.70
# address_type                       0.40
# park_facility_name                 0.07
# unique_key                         0.00
# created_date                       0.00
# agency                             0.00
# complaint_type                     0.00
# agency_name                        0.00
# status                             0.00
# community_board                    0.00
# police_precinct                    0.00
# park_borough                       0.00
# borough                            0.00
# open_data_channel_type             0.00
# dtype: float64

# %%
# null_percentage.to_csv('../data/abcd.csv')

# %% [markdown]
# <small>
#
# Always investigate columns that contain a high percentage of null values.
# In many cases, these nulls are **not errors** but are **logically dependent on other columns**, making them valid and meaningful.
#
# **Example:**
# - Columns: `vehicle_type`, `car_model`
# - If `vehicle_type` includes categories such as *car*, *bike*, or *truck*,
#   then `car_model` will only be populated when the vehicle type is **car**.
# - As a result, `car_model` may show a **high null percentage**, which is expected
#   because non-car records legitimately do not have a car model.
#
# </small>

# %% [markdown]
# ><small>
# >
# >💡 **Insight**
# >- For the columns with >95% nulls (e.g., taxi_company_borough, bridge_highway_name), the data is statistically >irrelevant. When a feature is missing for 99 out of 100 records, it ceases to be a variable and becomes an outlier >descriptor.
# >
# >- For the columns in the 30-55% range (e.g., intersection_street_1, landmark, cross_street_2), these are secondary >location descriptors. Since we have retained primary geolocation identifiers (likely incident_address, latitude, >longitude, or zip), these partial fields are redundant.
# ></small>

# %%
columns_with_null_perct_gt_30=list(null_percentage[null_percentage>30].index)

# %%
df.drop(columns=columns_with_null_perct_gt_30,inplace=True)

# %%
(df.isnull().sum()*100/len(df)).sort_values(ascending=False).round(2)
# Out:
# location_type                     9.45
# bbl                               7.85
# closed_date                       6.04
# city                              3.07
# street_name                       2.89
# incident_address                  2.89
# resolution_description            2.09
# resolution_action_updated_date    1.53
# council_district                  1.35
# descriptor                        1.16
# longitude                         0.96
# latitude                          0.96
# location                          0.96
# x_coordinate_state_plane          0.96
# y_coordinate_state_plane          0.95
# incident_zip                      0.70
# address_type                      0.40
# park_facility_name                0.07
# unique_key                        0.00
# agency                            0.00
# agency_name                       0.00
# complaint_type                    0.00
# created_date                      0.00
# status                            0.00
# community_board                   0.00
# borough                           0.00
# police_precinct                   0.00
# open_data_channel_type            0.00
# park_borough                      0.00
# dtype: float64

# %% [markdown]
# ### Analyze each column individually

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>These nulls act as status indicators. A null <b>closed_date</b> means the case is still open, and a missing resolution indicates the agency has not resolved it yet.</i><br><br>
# > • closed_date — 6.04%<br>
# > • resolution_description — 2.09%<br>
# > • resolution_action_updated_date — 1.53%<br>
# > <br>
# > <b>Action:</b> Replace <code>resolution_description</code> nulls with “Unspecified” for graph analysis
# > </small>

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>These define the “what” and “where” context. Losing these rows would waste valid data, so we label them as unknown.</i><br><br>
# > • location_type — 9.45%<br>
# > • descriptor — 1.16%<br>
# > • address_type — 0.40%<br>
# > <br>
# > <b>Action:</b> Fill with “Unspecified”
# > </small>

# %%
print(df.address_type.nunique())
df.address_type.value_counts()
# Out:
# 5
# address_type
# ADDRESS         302427
# INTERSECTION     16057
# BLOCKFACE         2202
# PLACE             1223
# PLACENAME          146
# Name: count, dtype: int64

# %%
print(df.location_type.nunique())
df.location_type.value_counts()
# Out:
# 113
# location_type
# RESIDENTIAL BUILDING             102839
# Street/Sidewalk                   74938
# Residential Building/House        58937
# Street                            20271
# Sidewalk                          15770
#                                   ...
# Single Room Occupancy (SRO)           1
# Street Vendor                         1
# Cafeteria - Private                   1
# Correctional Facility - State         1
# Theater                               1
# Name: count, Length: 113, dtype: int64

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>These are core spatial identifiers used for mapping. Since the analysis relies on geospatial EDA, rows without coordinates or ZIP codes are statistically unusable.</i><br><br>
# > • city — 3.07%<br>
# > • incident_address — 2.89%<br>
# > • council_district — 1.35%<br>
# > • latitude / longitude — 0.96%<br>
# > • location — 0.96%<br>
# > • x_coordinate_state_plane / y_coordinate_state_plane — 0.96%<br>
# > • incident_zip — 0.70%<br>
# > <br>
# > <b>Action:</b> Drop affected rows
# > </small>

# %%
df[['street_name','incident_address','city','location','longitude','latitude','incident_zip','police_precinct',"community_board"]]
# Out:
#              street_name       incident_address           city  \
# 0               1 AVENUE            93 1 AVENUE       NEW YORK
# 1       STRATFORD AVENUE  1349 STRATFORD AVENUE          BRONX
# 2          DEKALB AVENUE     3576 DEKALB AVENUE          BRONX
# 3           COURT STREET        44 COURT STREET       BROOKLYN
# 4         MONTAUK AVENUE     373 MONTAUK AVENUE       BROOKLYN
# ...                  ...                    ...            ...
# 323338           68 ROAD         144-43 68 ROAD       FLUSHING
# 323339     SHORE PARKWAY     2044 SHORE PARKWAY       BROOKLYN
# 323340  EAST  102 STREET   420 EAST  102 STREET       NEW YORK
# 323341    MCCLEAN AVENUE     200 MCCLEAN AVENUE  STATEN ISLAND
# 323342    DAHLGREN PLACE      77 DAHLGREN PLACE       BROOKLYN
#
#                                         location  longitude   latitude  \
# 0       POINT (-73.986326176505 40.726183323174) -73.986326  40.726183
# 1        POINT (-73.876391113118 40.83297318207) -73.876391  40.832973
# 2         POINT (-73.878834348657 40.8843456267) -73.878834  40.884346
# 3       POINT (-73.990963235578 40.692590626589) -73.990963  40.692591
# 4       POINT (-73.876734057579 40.669320633906) -73.876734  40.669321
# ...                                          ...        ...        ...
# 323338  POINT (-73.823795294901 40.732957874457) -73.823795  40.732958
# 323339  POINT (-73.991218860912 40.586136875112) -73.991219  40.586137
# 323340   POINT (-73.941138262803 40.78671817817) -73.941138  40.786718
# 323341   POINT (-74.06883485383 40.597249502152) -74.068835  40.597250
# 323342  POINT (-74.024302748851 40.617749211448) -74.024303  40.617749
#
#         incident_zip police_precinct   community_board
# 0            10003.0      Precinct 9      03 MANHATTAN
# 1            10472.0     Precinct 43          09 BRONX
# 2            10467.0     Precinct 52          07 BRONX
# 3            11201.0     Precinct 84       02 BROOKLYN
# 4            11208.0     Precinct 75       05 BROOKLYN
# ...              ...             ...               ...
# 323338       11367.0    Precinct 107         08 QUEENS
# 323339       11214.0     Precinct 60       13 BROOKLYN
# 323340       10029.0     Precinct 23      11 MANHATTAN
# 323341       10305.0    Precinct 122  02 STATEN ISLAND
# 323342       11228.0     Precinct 68       10 BROOKLYN
#
# [323343 rows x 9 columns]

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>The column <code>location</code> duplicates information already available in <code>longitude</code> and <code>latitude</code>, making it redundant.</i><br>
# > <b>Action:</b> Drop this column
# > </small>

# %% [markdown]
# ><small>
# >
# >💡 **Insight**
# >
# >**incident_address** is more granular and contains the complete information than **street_name**. As shown in above data, incident_address includes the specific building number plus the street name (e.g., "93 1 AVENUE"), whereas street_name is just the >generic road (e.g., "1 AVENUE").
# >
# ></small>

# %%
print(df.park_facility_name.nunique())

df.park_facility_name.value_counts()
# Out:
# 222
# park_facility_name
# Unspecified                                           322572
# Marcus Garvey Park                                       110
# St. Nicholas Park                                         25
# St. Mary's Park (Bronx)                                   24
# Maria Hernandez Park                                      15
#                                                        ...
# Harmony Park                                               1
# Willoughby Playground                                      1
# Bushwick Leaders High School for Academic Excellen         1
# Constance Baker Motley Recreation Center                   1
# Cypress Hills Ascend Charter School                        1
# Name: count, Length: 222, dtype: int64

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>The column <code>park_facility_name</code> contains mostly <code>Unspecified</code> values (over 322k), with only a few rows containing actual park names. This makes the column largely uninformative for analysis.</i><br>
# > <b>Action:</b> Drop this column
# > </small>

# %%
df[['park_borough','borough']]
# Out:
#          park_borough        borough
# 0           MANHATTAN      MANHATTAN
# 1               BRONX          BRONX
# 2               BRONX          BRONX
# 3            BROOKLYN       BROOKLYN
# 4            BROOKLYN       BROOKLYN
# ...               ...            ...
# 323338         QUEENS         QUEENS
# 323339       BROOKLYN       BROOKLYN
# 323340      MANHATTAN      MANHATTAN
# 323341  STATEN ISLAND  STATEN ISLAND
# 323342       BROOKLYN       BROOKLYN
#
# [323343 rows x 2 columns]

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>The column <code>park_borough</code> is redundant and duplicates the information in <code>borough</code>.</i><br>
# > <b>Action:</b> Drop this column
# > </small>

# %%
df[['agency','agency_name']]
# Out:
#        agency                                        agency_name
# 0       DOHMH            Department of Health and Mental Hygiene
# 1        NYPD                    New York City Police Department
# 2         HPD  Department of Housing Preservation and Develop...
# 3        NYPD                    New York City Police Department
# 4        NYPD                    New York City Police Department
# ...       ...                                                ...
# 323338   NYPD                    New York City Police Department
# 323339   NYPD                    New York City Police Department
# 323340   NYPD                    New York City Police Department
# 323341   NYPD                    New York City Police Department
# 323342   NYPD                    New York City Police Department
#
# [323343 rows x 2 columns]

# %% [markdown]
# > <small>
# > 💡 <b>Insight</b><br>
# > <i>The column <code>agency_name</code> is redundant, as it duplicates <code>agency</code>. The acronym is sufficient.</i><br>
# > <b>Action:</b> Drop this column
# > </small>

# %%
print(df.complaint_type.nunique())
df.complaint_type.value_counts()
# Out:
# 170
# complaint_type
# HEAT/HOT WATER             61940
# Noise - Residential        56344
# Illegal Parking            42775
# Blocked Driveway           15898
# UNSANITARY CONDITION        9472
#                            ...
# Radioactive Material           1
# Wayfinding                     1
# Taxi Licensee Complaint        1
# Borough Office                 1
# Tanning                        1
# Name: count, Length: 170, dtype: int64

# %%
print(df.police_precinct.nunique())
df.police_precinct.value_counts()
# Out:
# 78
# police_precinct
# Precinct 47     36216
# Precinct 44      8090
# Precinct 52      8017
# Precinct 75      7558
# Precinct 70      7131
#                 ...
# Precinct 69      1639
# Precinct 17      1621
# Precinct 26      1313
# Precinct 100      984
# Precinct 22       130
# Name: count, Length: 78, dtype: int64

# %%
print(df.bbl.nunique())
df.bbl.unique()
# Out:
# 85573
# array([1.00447003e+09, 2.03866005e+09, 2.03329002e+09, ...,
#        3.06133000e+09, 4.08892012e+09, 4.06533005e+09], shape=(85574,))

# %% [markdown]
# <small>
# Borough-Block-Lot - BBL is the unique identifier for NYC tax lots. We can keep this if we want to join this data with external housing data. But for this Analysis, we don't need this
# </small>

# %%
print(df.location_type.nunique())
df.location_type.value_counts()
# Out:
# 113
# location_type
# RESIDENTIAL BUILDING             102839
# Street/Sidewalk                   74938
# Residential Building/House        58937
# Street                            20271
# Sidewalk                          15770
#                                   ...
# Single Room Occupancy (SRO)           1
# Street Vendor                         1
# Cafeteria - Private                   1
# Correctional Facility - State         1
# Theater                               1
# Name: count, Length: 113, dtype: int64

# %%
print(df.community_board.nunique())
df.community_board.value_counts()
# Out:
# 77
# community_board
# 12 BRONX            36207
# 12 MANHATTAN         9911
# 04 BRONX             8084
# 07 BRONX             8011
# 05 BROOKLYN          7463
#                     ...
# 26 BRONX               17
# 95 STATEN ISLAND       13
# 56 BROOKLYN             4
# 84 QUEENS               2
# 27 BRONX                1
# Name: count, Length: 77, dtype: int64

# %%
df.incident_zip.nunique()
df.incident_zip.value_counts()
# Out:
# incident_zip
# 10466.0    32556
# 11226.0     5738
# 10467.0     4805
# 10458.0     4730
# 10456.0     4710
#            ...
# 17035.0        1
# 10152.0        1
# 89145.0        1
# 10045.0        1
# 10107.0        1
# Name: count, Length: 235, dtype: int64

# %%
df.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'address_type', 'city', 'status',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'council_district', 'police_precinct', 'bbl',
#        'borough', 'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location'],
#       dtype='str')

# %%
df[['location','latitude','longitude']].head()
# Out:
#                                    location   latitude  longitude
# 0  POINT (-73.986326176505 40.726183323174)  40.726183 -73.986326
# 1   POINT (-73.876391113118 40.83297318207)  40.832973 -73.876391
# 2    POINT (-73.878834348657 40.8843456267)  40.884346 -73.878834
# 3  POINT (-73.990963235578 40.692590626589)  40.692591 -73.990963
# 4  POINT (-73.876734057579 40.669320633906)  40.669321 -73.876734

# %%
df['open_data_channel_type'].value_counts()
# Out:
# open_data_channel_type
# ONLINE     148165
# MOBILE      86834
# PHONE       68195
# UNKNOWN     20149
# Name: count, dtype: int64

# %% [markdown]
# ##### Invalid data check

# %%
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:1025, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1024 try:
# -> 1025     result = pc_func(self._pa_array, other)
#    1026 except pa.ArrowNotImplementedError as err:
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pyarrow/compute.py:254, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     253     return Expression._call(func_name, list(args))
# --> 254 return func.call(args, None, memory_pool)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'subtract_checked' has no kernel matching input types (large_string, large_string)
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 invalid_data_mask=df['closed_date']-df['created_date'] < pd.Timedelta(0)
#       2 (invalid_data_mask).value_counts()
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
#    6750     self, other = self._align_for_op(other)
# -> 6751     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/base.py:1644, in IndexOpsMixin._arith_method(self, other, op)
#    1641     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1643 with np.errstate(all="ignore"):
# -> 1644     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1646 return self._construct_result(result, name=res_name, other=other)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:1075, in ArrowExtensionArray._arith_method(self, other, op)
#    1058 if (
#    1059     op in [operator.truediv, roperator.rtruediv]
#    1060     and isinstance(other, Path)
#    (...)   1065 ):
#    1066     # GH#61940
#    1067     return np.array(
#    1068         [
#    1069             op(x, other) if isinstance(x, str) else self.dtype.na_value
#    (...)   1072         dtype=object,
#    1073     )
# -> 1075 result = self._evaluate_op_method(other, op, ARROW_ARITHMETIC_FUNCS)
#    1076 if is_nan_na() and result.dtype.kind == "f":
#    1077     parr = result._pa_array
#
# File /workspaces/NYC_311_Request_DATA_ANALYSIS/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:1027, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1025     result = pc_func(self._pa_array, other)
#    1026 except pa.ArrowNotImplementedError as err:
# -> 1027     raise TypeError(self._op_method_error_message(other_original, op)) from err
#    1028 return self._from_pyarrow_array(result)
#
# TypeError: operation 'sub' not supported for dtype 'str' with dtype 'str'
