# %%
import pandas as pd

# %%
df=pd.read_parquet('../data/cleaned_data_dec_2025.parquet', engine='pyarrow')

# %%
df.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'address_type', 'city', 'status', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'council_district',
#        'police_precinct', 'borough', 'open_data_channel_type', 'latitude',
#        'longitude'],
#       dtype='str')

# %%
for index, row in df[['complaint_type','descriptor','resolution_description']].head(3).iterrows():
    print(row['complaint_type'], row['descriptor'], row['resolution_description'])
# Out:
# Food Poisoning 1 or 2 The Health Departmentâs Office of Environmental Investigations has determined this case was an isolated incident. The Departmentâs Bureau of Food Safety and Community Sanitation will review to see if a sanitary inspection is necessary. All food establishments are inspected annually. You can get results of all food safety inspections by going online to www.nyc.gov/health/restaurants.
# Noise - Residential Loud Music/Party The New York City Police Department responded to the complaint but officers were unable to gain entry into the premises. If the problem persists, please contact 311 to create another complaint and ensure that contact information (e.g., buzzer number, phone number, etc.) is available to assist the responding officers in gaining entry to properly investigate the complaint.  We count on New Yorkers like yourself to maintain a safe City, so please let us know if you see other conditions that require our attention.
# ...

# %%
df[['complaint_type','descriptor','resolution_description']].head(3)
# Out:
#         complaint_type        descriptor  \
# 0       Food Poisoning            1 or 2
# 1  Noise - Residential  Loud Music/Party
# 2       HEAT/HOT WATER    APARTMENT ONLY
#
#                               resolution_description
# 0  The Health Departmentâs Office of Environmen...
# 1  The New York City Police Department responded ...
# 2  HPD called the telephone number on file for th...
