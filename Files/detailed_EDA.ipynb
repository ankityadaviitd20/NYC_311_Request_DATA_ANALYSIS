# %% [markdown]
# To provide deep rather than surface-level analysis, I narrowed the audit scope to these specific agencies and complaint types. This ensures recommendations focus on the areas with the highest potential Return on Investment (ROI) for the city.

# %%
import pandas as pd

# %%
df=pd.read_parquet('../data/cleaned_data_dec_2025.parquet', engine='pyarrow')

# %%
scoped_df=    df[
        (df['complaint_type'].isin([
            'HEAT/HOT WATER',
            'Noise - Residential',
            'Illegal Parking'
        ]))
        &
        (df['agency'].isin([
            'NYPD',
            'HPD',
        ]))
    ]
# Out:
# 305019
